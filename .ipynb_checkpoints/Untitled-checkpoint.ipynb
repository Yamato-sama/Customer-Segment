# %% [markdown]
# # Import Library

# %%
#Dataset manipulation
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Online Retail.xlsx")
df
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 0         572891     23343                           20713      -400
# 1         581345    72800B   4 PURPLE FLOCK DINNER CANDLES        12
# 2         581168    72800B   4 PURPLE FLOCK DINNER CANDLES        12
# 3         581015    72800B   4 PURPLE FLOCK DINNER CANDLES        12
# 4         580876    72800B   4 PURPLE FLOCK DINNER CANDLES         1
# ...          ...       ...                             ...       ...
# 541904    536549    85226A                             NaN         1
# 541905    536547     37509                             NaN         1
# 541906    536546     22145                             NaN         1
# 541907    536545     21134                             NaN         1
# 541908    536414     22139                             NaN        56
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2011-10-26 14:14:00       0.00         NaN  United Kingdom
# ...

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.describe(include=['object'])
# Out:
#         InvoiceNo StockCode                         Description  \
# count      541909    541909                              540455
# unique      25900      4070                                4223
# top        573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq         1114      2313                                2369
#
#                Country
# count           541909
# unique              38
# top     United Kingdom
# freq            495478

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
duplicate = df[df.duplicated()]

# %%
print(duplicate)
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 14        577503    72800B     4 PURPLE FLOCK DINNER CANDLES         1
# 33        550459    72800B     4 PURPLE FLOCK DINNER CANDLES         1
# 180       580958     23345                 DOLLY GIRL BEAKER         2
# 196       578921     23345                 DOLLY GIRL BEAKER         1
# 217       575895     23345                 DOLLY GIRL BEAKER         1
# ...          ...       ...                               ...       ...
# 539427    545980     84836       ZINC METAL HEART DECORATION         2
# 539431    545872     84836       ZINC METAL HEART DECORATION         2
# 539475    543040     84836       ZINC METAL HEART DECORATION         1
# 539574    576559     23151         ZINC SWEETHEART SOAP DISH         1
# 540354    545166     84832  ZINC WILLIE WINKIE  CANDLE STICK         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
duplicate
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 517       536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527       536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537       536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539       536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555       536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# ...          ...       ...                                ...       ...
# 541675    581538     22068        BLACK PIRATE TREASURE CHEST         1
# 541689    581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 541692    581538     22992             REVOLVER WOODEN RULER          1
# 541699    581538     22694                       WICKER STAR          1
# 541701    581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df[df["Country"]=="Unspecified"]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 1111      564051     23007           SPACEBOY BABY GIFT SET         1
# 1130      559521     23007           SPACEBOY BABY GIFT SET         1
# 2300      561661     22906  12 MESSAGE CARDS WITH ENVELOPES         1
# 2301      561661     22906  12 MESSAGE CARDS WITH ENVELOPES         2
# 2549      576646     20973    12 PENCIL SMALL TUBE WOODLAND        24
# ...          ...       ...                              ...       ...
# 535931    552695     23233             WRAP POPPIES  DESIGN        25
# 536336    552695    16161U            WRAP SUKI AND FRIENDS        25
# 536563    552695     23232      WRAP VINTAGE PETALS  DESIGN        25
# 536656    559929     22709                 WRAP WEDDING DAY        25
# 539269    561658     84836      ZINC METAL HEART DECORATION         2
#
#                InvoiceDate  UnitPrice  CustomerID      Country
# 1111   2011-08-22 13:32:00      16.95     14265.0  Unspecified
# ...

# %%
qt = df["Quantity"].isin([25,24])
df[qt]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 66        578260     23437   50'S CHRISTMAS GIFT BAG LARGE        24
# 92        574029     23437   50'S CHRISTMAS GIFT BAG LARGE        24
# 109       572458     23437   50'S CHRISTMAS GIFT BAG LARGE        24
# 133       570964     23437   50'S CHRISTMAS GIFT BAG LARGE        24
# 143       569695     23437   50'S CHRISTMAS GIFT BAG LARGE        24
# ...          ...       ...                             ...       ...
# 541445    548535    90010A                             NaN        25
# 541472    548207     20713                             NaN        25
# 541501    547932     85197                             NaN        24
# 541543    547404    85028S                             NaN        24
# 541798    538249     85084                             NaN        25
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 66     2011-11-23 13:15:00       1.25     17469.0  United Kingdom
# ...

# %%
df.sort_values('Country',ascending= False)
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 280069    553857    84913B               MINT GREEN ROSE TOWEL         8
# 536563    552695     23232         WRAP VINTAGE PETALS  DESIGN        25
# 149975    561658     22750        FELTCRAFT PRINCESS LOLA DOLL         1
# 411524    561658     22752        SET 7 BABUSHKA NESTING BOXES         1
# 303041    549687     21977  PACK OF 60 PINK PAISLEY CAKE CASES        24
# ...          ...       ...                                 ...       ...
# 265651    563179     20726                  LUNCH BAG WOODLAND        10
# 51194     553546    47590A         BLUE HAPPY BIRTHDAY BUNTING        50
# 59448     560033     23319         BOX OF 6 MINI 50'S CRACKERS         6
# 534806    545475     22708                     WRAP DOLLY GIRL       200
# 504628    545475     21508             VINTAGE KID DOLLY CARD         72
#
#                InvoiceDate  UnitPrice  CustomerID      Country
# ...

# %%
df['InvoiceNo'].value_counts(normalize=True)
# Out:
# 573585     0.002056
# 581219     0.001382
# 581492     0.001349
# 580729     0.001330
# 558475     0.001301
#              ...
# 561687     0.000002
# 564529     0.000002
# C545672    0.000002
# C554862    0.000002
# 536414     0.000002
# Name: InvoiceNo, Length: 25900, dtype: float64

# %%
missing_in_per =np.round( df.isnull().sum()/df.shape[0] * 100,1)
missing_in_per
# Out:
# InvoiceNo       0.0
# StockCode       0.0
# Description     0.3
# Quantity        0.0
# InvoiceDate     0.0
# UnitPrice       0.0
# CustomerID     24.9
# Country         0.0
# dtype: float64

# %%
missing_in_num= df.isnull().sum()
missing_in_num
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
total = df.shape[0]
total
# Out:
# 541909

# %%
miss=pd.DataFrame({"Count":missing_in_num,"%":missing_in_per,"total":total})
miss
# Out:
#               Count     %   total
# InvoiceNo         0   0.0  541909
# StockCode         0   0.0  541909
# Description    1454   0.3  541909
# Quantity          0   0.0  541909
# InvoiceDate       0   0.0  541909
# UnitPrice         0   0.0  541909
# CustomerID   135080  24.9  541909
# Country           0   0.0  541909

# %%
# Out:
# (541909, 8)
